# %% [markdown]
# # SP24BUAN651FO - Introduction to Data and Programming - Final Project

# %% [markdown]
# **Sacred Heart University - Jack Welch College of Business & Technology** </br>
#
# **Instructor: Prof. Trevor Michelson** </br>
# **Student: Thamson Antony Arockiasamy - arockiasamyt**

# %% [markdown]
# ## Project Title: Weather Data Analysis
#
# ADD DESCRIPTION HERE

# %% [markdown]
# ## 1. Housekeeping

# %%
# Importing necessary libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import constants

# %%
# Reading input file

data = pd.read_csv('Weather Data.csv')
data
# Out:
#              Date/Time  Temp_C  Wind Speed_km/h              Weather
# 0        01/01/12 0:00    -1.8                4                   Fog
# 1        01/01/12 1:00    -1.8                4                   Fog
# 2        01/01/12 2:00    -1.8                7  Freezing Drizzle,Fog
# 3        01/01/12 3:00    -1.5                6  Freezing Drizzle,Fog
# 4        01/01/12 4:00    -1.5                7                   Fog
# ...                ...     ...              ...                   ...
# 8779  12/31/2012 19:00     0.1               30                  Snow
# 8780  12/31/2012 20:00     0.2               24                  Snow
# 8781  12/31/2012 21:00    -0.5               28                  Snow
# 8782  12/31/2012 22:00    -0.2               28                  Snow
# 8783  12/31/2012 23:00     0.0               30                  Snow
#
# [8784 rows x 4 columns]

# %% [markdown]
# ## 2. Analyzing Continuous Values

# %% [markdown]
# ### 2.1. Analyzing the Temperature

# %%
# Understanding the frequency distribution of the Temperature recored

plt.figure(figsize=(8, 6))
plt.hist(data['Temp_C'], bins=20, color='green', alpha=0.7)
plt.xlabel('Tempareture')
plt.ylabel('Frequency')
plt.title('Temperature Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.2. Analyzing the Wind Speed

# %%
plt.figure(figsize=(8, 6))
plt.hist(data['Wind Speed_km/h'], bins=20, color='blue', alpha=0.7)
plt.xlabel('Wind Speed')
plt.ylabel('Frequency')
plt.title('Wind Speed Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Analyzing the Categorical Value
