# %% [markdown]
# # SP24BUAN651FO - Introduction to Data and Programming - Project - arockiasamyt

# %% [markdown]
# <hr class="solid"> <H2> Sacred Heart University - Jack Welch College of Business & Technology </br>
# <H4> <b> Instructor: </b> Prof. Trevor Michelson </br>
# <b> Student: </b> Thamson Antony Arockiasamy (0940430-arockiasamyt) - MS in Business Analytics - Spring 2024</H4>
#
# <h4> <a href='https://github.com/thamsonantony/SP24BUAN651FO-Intro-to-Data-and-Programming-Final-Project'> GitHub Repo </a> </h4>

# %% [markdown]
# ## <hr class="solid"> Project Summary: Option 2 - Weather Data Analysis

# %% [markdown]
# <H3> Objective:
#
# <H5> To accomplish below tasks:
#   <ul>
#     <li>Analyze the dependent variables of temperature and windspeed recorded during 2012 by plotting distribution separately and recording observations based on the plots. </li>
#     <li>Analyze the categorical value of weather by plotting such as distibution, counts and recording observations based on the plots.</li>
#     <li>Analyze the relationship/correlations between the dependent continuous values and  generate necessary plots to depict the relationship between them. Deriving conclusions based on the plots </li>
#     <li>Deriving conclusions by analyzing the relationship between the dependent continuous values and the categorical value of weather by plotting graphs containting all the available data</li>
#   </ul>
# </H5>
#
# <H3> Input Information: </H3>
#
# <table>
#
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Column</th>
#       <th>Data Type</th>
#       <th>Description</th>
#       <th>Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Date & Hour</td>
#       <td>Date/Time</td>
#       <td>MM/DD/YY HH:MM</td>
#       <td>Date and Hour</td>
#       <td>Independent</td>
#     </tr>
#     <tr>
#       <td>Temperature</td>
#       <td>Temp_C</td>
#       <td>Float</td>
#       <td>Temperature in Celcius</td>
#       <td>Dependent - Continuous</td>
#     </tr>
#     <tr>
#       <td>Dew Point</td>
#       <td>Dew Point Temp_C</td>
#       <td>Integer</td>
#       <td>Dew Point Temperature</td>
#       <td>Dependent - Continuous</td>
#     </tr>
#     <tr>
#       <td>Humidity</td>
#       <td>Rel Hum_%</td>
#       <td>Percentage</td>
#       <td>Humidity</td>
#       <td>Dependent - Continuous</td>
#     </tr>
#     <tr>
#       <td>Wind Speed </td>
#       <td>Wind_Speed_Km/h</td>
#       <td>Integer</td>
#       <td>Wind Speed in Kilometers per Hour</td>
#       <td>Dependent - Continuous</td>
#     </tr>
#     <tr>
#       <td>Visibility</td>
#       <td>Visibility_km</td>
#       <td>Integer</td>
#       <td>Visibility</td>
#       <td>Dependent - Continuous</td>
#     </tr>
#     <tr>
#       <td>Pressure </td>
#       <td>Pressure_kPa</td>
#       <td>Integer</td>
#       <td>Pressure Kilo Pascal</td>
#       <td>Dependent - Continuous</td>
#     </tr>
#     <tr>
#       <td>Weather</td>
#       <td>Weather</td>
#       <td>String</td>
#       <td>Weather Description</td>
#       <td>Categorical</td>
#     </tr>
#   </tbody>
# </table>
#
# <H3> Source: </h3> <H4> <a href='https://www.kaggle.com/datasets/bhanupratapbiswas/weather-data'> Input Dataset in Kaggle </a> </H4>

# %% [markdown]
# ## <hr class="solid"> Contents

# %% [markdown]
# 1. [Housekeeping](#sec1)
# 2. [Analyzing Continuous Values](#sec2)
# 3. [Analyzing the Categorical Value](#sec3)
# 4. [Relationship between continuous values](#sec4)
# 5. [Relationship between a numerical and categorical value](#sec5)
# 6. [Conclusion](#sec6)

# %% [markdown]
# ## <hr class="solid"> 1. Housekeeping <a id='sec1'></a>

# %%
# Importing necessary libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import constants

# %%
# Reading input file

data = pd.read_csv('Weather Data.csv')
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## <hr class="solid">2. Analyzing the Continuous Value - Temperature <a id='sec2'></a>

# %% [markdown]
# ### 2.1. General Statistical Analysis

# %%
# using pandas
min_value = data['Temp_C'].min()
max_value = data['Temp_C'].max()
quantiles = data['Temp_C'].quantile([0.25, 0.5, 0.75])

# using numpy
mean = np.mean(data['Temp_C'])
median = np.median(data['Temp_C'])
std_dev = np.std(data['Temp_C'])

print(f"Minimum Temperature: {min_value}")
print(f"Maximum Temperature: {max_value}")
print(f"Mean Temperature: {mean}")
print(f"Median Temperature: {median}")
print(f"Standard Deviation in Temperature: {std_dev}")
print("Quantiles:")
print(quantiles)
# Out:
# Minimum Temperature: -23.3
# Maximum Temperature: 33.0
# Mean Temperature: 8.798144353369764
# Median Temperature: 9.3
# Standard Deviation in Temperature: 11.687217456881825
# Quantiles:
# 0.25     0.1
# 0.50     9.3
# 0.75    18.8
# Name: Temp_C, dtype: float64

# %% [markdown]
# ### 2.2. Analyzing the Temperature

# %% [markdown]
# #### 2.2.1. Understanding the trend of the Temperature recored

# %%
data['Dt'] = pd.to_datetime(data['Date/Time'])
plt.figure(figsize=(15, 6))
plt.plot(data.index, data['Temp_C'], color='green')
plt.xlabel('Date/Time')
plt.ylabel('Temperature')
plt.title('Temperature Time Series Plot')
plt.show()

# %% [markdown]
# #### 2.2.2. Understanding the frequency distribution of the Temperature recored

# %%
plt.figure(figsize=(15, 6))
plt.hist(data['Temp_C'], bins=20, color='green', alpha=0.7)
plt.xlabel('Tempareture')
plt.ylabel('Frequency')
plt.title('Temperature Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3. Finding Outliers Values

# %% [markdown]
# <H4> Using Z-Score

# %%
data['Z_Score'] = (data['Temp_C'] - data['Temp_C'].mean()) / data['Temp_C'].std()
threshold = 5
outliers = data[abs(data['Z_Score']) > threshold]
print("Outliers identified using z-score method:")
outliers
# Out:
# Outliers identified using z-score method:
# Empty DataFrame
# Columns: [Date/Time, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather, Dt, Z_Score]
# Index: []

# %% [markdown]
# <H4> Using BoxPlot

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(data['Temp_C'], patch_artist=True, boxprops=dict(facecolor='green'))
plt.xlabel('Temperature')
plt.ylabel('Value')
plt.title('Box Plot of Temperature Data')
plt.show()

# %% [markdown]
# ### 2.4. Observations

# %% [markdown]
# 1. TBA

# %% [markdown]
# ## <hr class="solid"> 3. Analyzing the Categorical Value - Weather <a id='sec3'></a>

# %% [markdown]
# ### 3.1. General Statistical Analysis

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# #### 3.1.2. Mean of the values grouped by Weather classification

# %%
data=data.drop(columns='Dt')
df_ex=data.drop(columns='Date/Time')
df_ex.groupby('Weather').mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# #### 3.1.3. Minimum values of each weather classification

# %%
df_ex.groupby('Weather').min()
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                                     -23.3             -28.5         20
# Cloudy                                    -21.4             -26.8         18
# Drizzle                                     1.1              -0.2         74
# Drizzle,Fog                                 0.0              -1.6         85
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                0.9               0.1         92
# Drizzle,Snow,Fog                            0.3              -0.1         92
# Fog                                       -16.0             -17.2         80
# Freezing Drizzle                           -9.0             -12.2         78
# Freezing Drizzle,Fog                       -6.4              -9.0         82
# Freezing Drizzle,Haze                      -5.8              -8.3         81
# ...

# %% [markdown]
# #### 3.1.4. Maximum values of each weather classification

# %%
df_ex.groupby('Weather').max()
# Out:
#                                          Temp_C  Dew Point Temp_C  Rel Hum_%  \
# Weather
# Clear                                      32.8              20.4         99
# Cloudy                                     30.5              22.6         99
# Drizzle                                    18.8              17.7         96
# Drizzle,Fog                                19.9              19.1        100
# Drizzle,Ice Pellets,Fog                     0.4              -0.7         92
# Drizzle,Snow                                1.2               0.2         95
# Drizzle,Snow,Fog                            1.1               0.6         98
# Fog                                        20.8              19.6        100
# Freezing Drizzle                           -2.3              -3.3         93
# Freezing Drizzle,Fog                       -0.3              -2.3         94
# Freezing Drizzle,Haze                      -5.0              -7.7         83
# ...

# %% [markdown]
# ### 3.2. EDA Plots

# %% [markdown]
# #### 3.2.1. Plotting the count

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Weather', data=data, palette='viridis')
plt.xlabel('Weather')
plt.ylabel('Count')
plt.title('Weather Counts')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.2.2. Pie Chart of Weather Propotions

# %%
data['Weather'].value_counts().iloc[:10].plot.pie(title='Weather conditions proportions' , figsize=(10,8) , autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Weather conditions proportions'}, ylabel='count'>

# %% [markdown]
# ### 3.3. Observations

# %% [markdown]
# 1. TBA

# %% [markdown]
# ## <hr class="solid"> 4. Relationship between continuous values  <a id='sec4'></a>

# %% [markdown]
# ### 4.1. Continuous Values to be Analyzed

# %% [markdown]
# <h4> 1. Temperature </br>
# 2. Humidity </h4>

# %% [markdown]
# ### 4.2. Science behind the relationship of these continuous values

# %% [markdown]
# <H4> The relationship between temperature and humidity is governed by thermodynamics and water vapor behavior. Warm air can hold more water vapor, increasing humidity. Relative humidity (RH) compares the current water vapor content to the maximum possible at a given temperature. Higher temperatures can lower RH if moisture remains constant, and vice versa. Dew point temperature is when air becomes saturated, forming dew. This relationship affects human comfort and weather, influencing phenomena like fog and precipitation. Understanding it aids in weather prediction and assessing environmental conditions. </H4>

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather', 'Z_Score'],
#       dtype='object')

# %% [markdown]
# ### 4.3. Scatterplots and Correlation

# %%
plt.figure(figsize=(15, 6))
plt.scatter(data['Temp_C'], data['Rel Hum_%'], color='skyblue')
plt.xlabel('Temperature')
plt.ylabel('Temperature')
plt.title('Scatter Plot of Two Continuous Variables')
plt.grid(True)
plt.show()

# %%
corr_matrix = data[['Temp_C', 'Rel Hum_%']].corr()
plt.figure(figsize=(15, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 12})
plt.title('Correlation Heatmap between Temperature and Humidity')
plt.show()

# %% [markdown]
# ### 4.4 Observations

# %% [markdown]
# 1. TBA

# %% [markdown]
# ## <hr class="solid"> 5. Relationship between a numerical and a categorical value <a id='sec5'></a>`

# %% [markdown]
# ### 5.1. Values to be analyzed

# %% [markdown]
# <H4> 1. Temperature </br>
# 2. Weather </H4>

# %% [markdown]
# ### 5.2. Science behind the relation between the numerival and categorical value

# %% [markdown]
# <h4> - Temperature influences the formation and behavior of weather phenomena such as clouds, precipitation, fog, thunderstorms, and winds. </br>
# - Warm temperatures can lead to the evaporation of water from the Earth's surface, which contributes to the formation of clouds and precipitation when the moist air rises and cools. </br>
# - Temperature gradients in the atmosphere can drive the movement of air masses, leading to changes in weather patterns and the development of wind systems. </h4>

# %% [markdown]
# ### 5.3. Plotting the relationship

# %% [markdown]
# #### 5.3.1. Box Plot

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=data, x='Weather', y='Temp_C')
plt.xticks(rotation=45)
plt.title('Box Plot of Temperature by Weather')
plt.xlabel('Weather')
plt.ylabel('Temperature (Celsius)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### 5.3.2. Kernel Density Plot

# %%
plt.figure(figsize=(25, 15))
sns.kdeplot(
    data=data,
    x="Temp_C",
    hue="Weather",
    common_norm=False
)
plt.title("Kernel Density Plot - Numerical Value by Category")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/k1/6_bp9c1n79z2_29r5qj44c700000gn/T/ipykernel_32150/3687830875.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %% [markdown]
# ### 5.4 Observations

# %% [markdown]
# 1. TBA

# %% [markdown]
# ## <hr class="solid"> 6. Conclusion <a id='sec6'></a>

# %% [markdown]
# <H3> Heading

# %% [markdown]
# <H4> Test

# %% [markdown]
# <hr class="solid">
